# %%
import pandas as pd

# %%
df = pd.read_csv("Upper West Side Restaurant Prices 2024 and 2019 - Sheet1.csv")

# %%
df
# Out:
#           Restaurant               Type              Appetizer  2024 App $  \
# 0             RedFarm           Chinese       BBQ'D SPARE RIBS       26.00
# 1     Happy Hot Hunan           Chinese  Hunan Pickled Veggies        7.45
# 2   Barney Greengrass       Jewish Deli               Sturgeon       25.00
# 3           Jing Fong           Chinese       Shrimp Dumplings        8.25
# 4     Jacob's Pickles  Southern Comfort         Fried Pickles        14.00
# 5                Land              Thai    Veggie Spring Rolls       11.00
# 6     5 Napkin Burger           Burgers          Buffalo Wings       13.75
# 7  Good Enough To Eat          American             Three Eggs       14.00
#
#    2019 Appetizer $                                     Main Dish  \
# 0             19.00                           Three Chili Chicken
# 1              5.55            Shredded Beef w Spicy Green Pepper
# 2             22.50  Nova Scotia Salmon Scrambled w Eggs & Onions
# ...

# %%
df['2024 App $'].sum()
# Out:
# 119.45

# %%
df['2019 Appetizer $'].sum()
# Out:
# 91.0

# %%
(119.45 - 91) / 91 *100
# Out:
# 31.26373626373627

# %%
print("Appetizers Have Increased in price by 31 percent in 5 years")
# Out:
# Appetizers Have Increased in price by 31 percent in 5 years

# %%
df['2024 Main $'].sum()
# Out:
# 177.0

# %%
df['2019 Main $'].sum()
# Out:
# 142.4

# %%
(177 - 142.4) / 142.4 * 100
# Out:
# 24.29775280898876

# %%
print("Main dishes Have increased in price by 24 percent in 5 years")
# Out:
# Main dishes Have increased in price by 24 percent in 5 years

# %%
df['2024 Dessert $'].sum()
# Out:
# 66.75

# %%
66.75 - 16 - 12
# Out:
# 38.75

# %%
print("subtracting 16 and 12 because RedFarm and Land did have dessert on the menu in 2019 and thus there is nothing to compare the 2024 dessert price to")
# Out:
# subtracting 16 and 12 because RedFarm and Land did have dessert on the menu in 2019 and thus there is nothing to compare the 2024 dessert price to

# %%
df['2019 Dessert $'].sum()
# Out:
# 32.45

# %%
(38.75 - 32.45) / 32.45 * 100
# Out:
# 19.414483821263474

# %%
print("Desserts have increased in price by 19 percent in 5 years")
# Out:
# Desserts have increased in price by 19 percent in 5 years

# %%
print("According to the CPI Inflation Calculator, prices have increased 22 percent between 2019 and 2024")
# Out:
# According to the CPI Inflation Calculator, prices have increased 22 percent between 2019 and 2024

# %%
df
# Out:
#           Restaurant               Type              Appetizer  2024 App $  \
# 0             RedFarm           Chinese       BBQ'D SPARE RIBS       26.00
# 1     Happy Hot Hunan           Chinese  Hunan Pickled Veggies        7.45
# 2   Barney Greengrass       Jewish Deli               Sturgeon       25.00
# 3           Jing Fong           Chinese       Shrimp Dumplings        8.25
# 4     Jacob's Pickles  Southern Comfort         Fried Pickles        14.00
# 5                Land              Thai    Veggie Spring Rolls       11.00
# 6     5 Napkin Burger           Burgers          Buffalo Wings       13.75
# 7  Good Enough To Eat          American             Three Eggs       14.00
#
#    2019 Appetizer $                                     Main Dish  \
# 0             19.00                           Three Chili Chicken
# 1              5.55            Shredded Beef w Spicy Green Pepper
# 2             22.50  Nova Scotia Salmon Scrambled w Eggs & Onions
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("Upper West Side Restaurant Prices 2024 and 2019 - Sheet1.csv")

# %%
df
# Out:
#           Restaurant               Type              Appetizer  2024 App $  \
# 0             RedFarm           Chinese       BBQ'D SPARE RIBS       26.00
# 1     Happy Hot Hunan           Chinese  Hunan Pickled Veggies        7.45
# 2   Barney Greengrass       Jewish Deli               Sturgeon       25.00
# 3           Jing Fong           Chinese       Shrimp Dumplings        8.25
# 4     Jacob's Pickles  Southern Comfort         Fried Pickles        14.00
# 5                Land              Thai    Veggie Spring Rolls       11.00
# 6     5 Napkin Burger           Burgers          Buffalo Wings       13.75
# 7  Good Enough To Eat          American             Three Eggs       14.00
#
#    2019 Appetizer $                                     Main Dish  \
# 0             19.00                           Three Chili Chicken
# 1              5.55            Shredded Beef w Spicy Green Pepper
# 2             22.50  Nova Scotia Salmon Scrambled w Eggs & Onions
# ...

# %%
##creating a new column calculating the percentage rise for main dishes 
df['main_dish_percentage_rise'] = (df['2024 Main $'] - df['2019 Main $']) / df['2019 Main $']

# %%
df
# Out:
#           Restaurant               Type              Appetizer  2024 App $  \
# 0             RedFarm           Chinese       BBQ'D SPARE RIBS       26.00
# 1     Happy Hot Hunan           Chinese  Hunan Pickled Veggies        7.45
# 2   Barney Greengrass       Jewish Deli               Sturgeon       25.00
# 3           Jing Fong           Chinese       Shrimp Dumplings        8.25
# 4     Jacob's Pickles  Southern Comfort         Fried Pickles        14.00
# 5                Land              Thai    Veggie Spring Rolls       11.00
# 6     5 Napkin Burger           Burgers          Buffalo Wings       13.75
# 7  Good Enough To Eat          American             Three Eggs       14.00
#
#    2019 Appetizer $                                     Main Dish  \
# 0             19.00                           Three Chili Chicken
# 1              5.55            Shredded Beef w Spicy Green Pepper
# 2             22.50  Nova Scotia Salmon Scrambled w Eggs & Onions
# ...

# %%
df.to_csv('restaurant_prices.csv', index=False)

# %%
df['CPI Inflation'] = .22

# %%
df
# Out:
#           Restaurant               Type              Appetizer  2024 App $  \
# 0             RedFarm           Chinese       BBQ'D SPARE RIBS       26.00
# 1     Happy Hot Hunan           Chinese  Hunan Pickled Veggies        7.45
# 2   Barney Greengrass       Jewish Deli               Sturgeon       25.00
# 3           Jing Fong           Chinese       Shrimp Dumplings        8.25
# 4     Jacob's Pickles  Southern Comfort         Fried Pickles        14.00
# 5                Land              Thai    Veggie Spring Rolls       11.00
# 6     5 Napkin Burger           Burgers          Buffalo Wings       13.75
# 7  Good Enough To Eat          American             Three Eggs       14.00
#
#    2019 Appetizer $                                     Main Dish  \
# 0             19.00                           Three Chili Chicken
# 1              5.55            Shredded Beef w Spicy Green Pepper
# 2             22.50  Nova Scotia Salmon Scrambled w Eggs & Onions
# ...

# %%
df.to_csv('restaurant_pricesJuly9th.csv', index=False)

# %%
df = df.drop('CPI Inflation', axis=1)

# %%
df
# Out:
#           Restaurant               Type              Appetizer  2024 App $  \
# 0             RedFarm           Chinese       BBQ'D SPARE RIBS       26.00
# 1     Happy Hot Hunan           Chinese  Hunan Pickled Veggies        7.45
# 2   Barney Greengrass       Jewish Deli               Sturgeon       25.00
# 3           Jing Fong           Chinese       Shrimp Dumplings        8.25
# 4     Jacob's Pickles  Southern Comfort         Fried Pickles        14.00
# 5                Land              Thai    Veggie Spring Rolls       11.00
# 6     5 Napkin Burger           Burgers          Buffalo Wings       13.75
# 7  Good Enough To Eat          American             Three Eggs       14.00
#
#    2019 Appetizer $                                     Main Dish  \
# 0             19.00                           Three Chili Chicken
# 1              5.55            Shredded Beef w Spicy Green Pepper
# 2             22.50  Nova Scotia Salmon Scrambled w Eggs & Onions
# ...
